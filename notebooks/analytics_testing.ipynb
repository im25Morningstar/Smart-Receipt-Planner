# %%
import uuid
from datetime import datetime

dummy_receipts = [
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "McDonald's",
        "date": datetime(2024, 12, 1),
        "total": 320.50,
        "category": "food",
        "raw_text_lines": ["McDonald's Bill", "Burger Combo", "Total: 320.50"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Big Bazaar",
        "date": datetime(2024, 12, 2),
        "total": 780.00,
        "category": "groceries",
        "raw_text_lines": ["Big Bazaar", "Vegetables", "Total: 780.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Uber",
        "date": datetime(2024, 12, 2),
        "total": 215.00,
        "category": "travel",
        "raw_text_lines": ["Uber Ride", "Trip Fare", "Total: 215.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Amazon",
        "date": datetime(2024, 12, 3),
        "total": 1520.00,
        "category": "shopping",
        "raw_text_lines": ["Amazon Invoice", "Laptop Stand", "Total: 1520.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Apollo Pharmacy",
        "date": datetime(2024, 12, 4),
        "total": 450.00,
        "category": "healthcare",
        "raw_text_lines": ["Apollo Pharmacy", "Medicines", "Total: 450.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Jio Fiber",
        "date": datetime(2024, 12, 5),
        "total": 999.00,
        "category": "utilities",
        "raw_text_lines": ["Jio Fiber Bill", "Monthly Charge", "Total: 999.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Dominos",
        "date": datetime(2024, 12, 6),
        "total": 620.00,
        "category": "food",
        "raw_text_lines": ["Dominos Pizza", "Order #123", "Total: 620.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "DMart",
        "date": datetime(2024, 12, 7),
        "total": 990.00,
        "category": "groceries",
        "raw_text_lines": ["DMart Bill", "Groceries", "Total: 990.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Rapido",
        "date": datetime(2024, 12, 7),
        "total": 120.00,
        "category": "travel",
        "raw_text_lines": ["Rapido Ride", "Fare", "Total: 120.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Reliance Digital",
        "date": datetime(2024, 12, 8),
        "total": 2300.00,
        "category": "shopping",
        "raw_text_lines": ["Reliance Digital", "Headphones", "Total: 2300.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Clinic Plus",
        "date": datetime(2024, 12, 9),
        "total": 200.00,
        "category": "misc",
        "raw_text_lines": ["Clinic Plus", "Misc Items", "Total: 200.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Starbucks",
        "date": datetime(2024, 12, 10),
        "total": 450.00,
        "category": "food",
        "raw_text_lines": ["Starbucks Coffee", "Latte", "Total: 450.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Fresh Market",
        "date": datetime(2024, 12, 11),
        "total": 700.00,
        "category": "groceries",
        "raw_text_lines": ["Fresh Market", "Vegetables & Fruits", "Total: 700.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "Air India",
        "date": datetime(2024, 12, 12),
        "total": 5400.00,
        "category": "travel",
        "raw_text_lines": ["Air India", "Flight Booking", "Total: 5400.00"]
    },
    {
        "receipt_id": str(uuid.uuid4()),
        "vendor": "BSES Grid",
        "date": datetime(2024, 12, 12),
        "total": 1400.00,
        "category": "utilities",
        "raw_text_lines": ["Electricity Bill", "BSES", "Total: 1400.00"]
    },
]

# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

# %%
import importlib
from app.utils import analytics
importlib.reload(analytics)
from app.utils.analytics import(
    category_breakdown,monthly_summary,weekly_spend
)

# %%
category_breakdown(dummy_receipts)
# Out:
# {'food': 1390.5,
#  'groceries': 2470.0,
#  'travel': 5735.0,
#  'shopping': 3820.0,
#  'healthcare': 450.0,
#  'utilities': 2399.0,
#  'misc': 200.0}

# %%
monthly_summary(dummy_receipts)
# Out:
# {'month': '2024-12',
#  'month_name': 'December',
#  'total_spend': 16464.5,
#  'num_receipts': 15,
#  'avg_per_day': 1372.04}

# %%
weekly_spend(dummy_receipts)
# Out:
# [{'week': 1, 'total': 6014.5}, {'week': 2, 'total': 10450.0}]
