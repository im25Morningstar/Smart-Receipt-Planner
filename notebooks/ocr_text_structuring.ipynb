# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.24.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.2)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.5.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2025.12.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.3)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 28.7 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.5 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 63.4 MB/s eta 0:00:00
# Downloading python_bidi-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 21.9 MB/s eta 0:00:00
# Installing collected packages: python-bidi, pyclipper, ninja, easyocr
# Successfully installed easyocr-1.7.2 ninja-1.13.0 pyclipper-1.4.0 python-bidi-0.6.7

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
# !unzip receipt_validation.zip -d data/
# Out:
# Archive:  receipt_validation.zip
#    creating: data/receipt_validation/
#    creating: data/receipt_validation/train/
#    creating: data/receipt_validation/train/non_receipt/
#   inflating: data/receipt_validation/train/non_receipt/1.jpg
#   inflating: data/receipt_validation/train/non_receipt/2.jpg
#   inflating: data/receipt_validation/train/non_receipt/22903.jpg
#   inflating: data/receipt_validation/train/non_receipt/22907.jpg
#   inflating: data/receipt_validation/train/non_receipt/22908.jpg
#   inflating: data/receipt_validation/train/non_receipt/22911.jpg
#   inflating: data/receipt_validation/train/non_receipt/22912.jpg
#   inflating: data/receipt_validation/train/non_receipt/22913.jpg
#   inflating: data/receipt_validation/train/non_receipt/22915.jpg
#   inflating: data/receipt_validation/train/non_receipt/22917.jpg
#   inflating: data/receipt_validation/train/non_receipt/22919.jpg
#   inflating: data/receipt_validation/train/non_receipt/22920.jpg
#   inflating: data/receipt_validation/train/non_receipt/22921.jpg
#   inflating: data/receipt_validation/train/non_receipt/22924.jpg
#   inflating: data/receipt_validation/train/non_receipt/22925.jpg
#   inflating: data/receipt_validation/train/non_receipt/22927.jpg
#   inflating: data/receipt_validation/train/non_receipt/22928.jpg
#   inflating: data/receipt_validation/train/non_receipt/22930.jpg
#   inflating: data/receipt_validation/train/non_receipt/22933.jpg
#   inflating: data/receipt_validation/train/non_receipt/22934.jpg
#   inflating: data/receipt_validation/train/non_receipt/22935.jpg
#   inflating: data/receipt_validation/train/non_receipt/22936.jpg
#   inflating: data/receipt_validation/train/non_receipt/22938.jpg
#   inflating: data/receipt_validation/train/non_receipt/22941.jpg
#   inflating: data/receipt_validation/train/non_receipt/22942.jpg
#   inflating: data/receipt_validation/train/non_receipt/22943.jpg
#   inflating: data/receipt_validation/train/non_receipt/22944.jpg
#   inflating: data/receipt_validation/train/non_receipt/22947.jpg
#   inflating: data/receipt_validation/train/non_receipt/22948.jpg
#   inflating: data/receipt_validation/train/non_receipt/22949.jpg
#   inflating: data/receipt_validation/train/non_receipt/22950.jpg
#   inflating: data/receipt_validation/train/non_receipt/22951.jpg
#   inflating: data/receipt_validation/train/non_receipt/22952.jpg
#   inflating: data/receipt_validation/train/non_receipt/22953.jpg
#   inflating: data/receipt_validation/train/non_receipt/22954.jpg
#   inflating: data/receipt_validation/train/non_receipt/22955.jpg
#   inflating: data/receipt_validation/train/non_receipt/22956.jpg
#   inflating: data/receipt_validation/train/non_receipt/22958.jpg
#   inflating: data/receipt_validation/train/non_receipt/22959.jpg
#   inflating: data/receipt_validation/train/non_receipt/22960.jpg
#   inflating: data/receipt_validation/train/non_receipt/22961.jpg
#   inflating: data/receipt_validation/train/non_receipt/22962.jpg
#   inflating: data/receipt_validation/train/non_receipt/22963.jpg
#   inflating: data/receipt_validation/train/non_receipt/22964.jpg
#   inflating: data/receipt_validation/train/non_receipt/22965.jpg
#   inflating: data/receipt_validation/train/non_receipt/22966.jpg
#   inflating: data/receipt_validation/train/non_receipt/22967.jpg
#   inflating: data/receipt_validation/train/non_receipt/22969.jpg
#   inflating: data/receipt_validation/train/non_receipt/22970.jpg
#   inflating: data/receipt_validation/train/non_receipt/22971.jpg
#   inflating: data/receipt_validation/train/non_receipt/22973.jpg
#   inflating: data/receipt_validation/train/non_receipt/22974.jpg
#   inflating: data/receipt_validation/train/non_receipt/3.jpg
#   inflating: data/receipt_validation/train/non_receipt/4.png
#   inflating: data/receipt_validation/train/non_receipt/5.jpg
#   inflating: data/receipt_validation/train/non_receipt/50.jpg
#   inflating: data/receipt_validation/train/non_receipt/51.jpg
#   inflating: data/receipt_validation/train/non_receipt/52.jpg
#   inflating: data/receipt_validation/train/non_receipt/53.jpg
#   inflating: data/receipt_validation/train/non_receipt/54.jpg
#   inflating: data/receipt_validation/train/non_receipt/55.jpg
#   inflating: data/receipt_validation/train/non_receipt/56.jpg
#   inflating: data/receipt_validation/train/non_receipt/57.jpg
#   inflating: data/receipt_validation/train/non_receipt/58.jpg
#   inflating: data/receipt_validation/train/non_receipt/59.jpg
#   inflating: data/receipt_validation/train/non_receipt/6.png
#   inflating: data/receipt_validation/train/non_receipt/60.jpg
#   inflating: data/receipt_validation/train/non_receipt/61.jpg
#   inflating: data/receipt_validation/train/non_receipt/62.jpg
#   inflating: data/receipt_validation/train/non_receipt/63.jpg
#   inflating: data/receipt_validation/train/non_receipt/64.jpg
#   inflating: data/receipt_validation/train/non_receipt/7.png
#   inflating: data/receipt_validation/train/non_receipt/ID_2.jpg
#   inflating: data/receipt_validation/train/non_receipt/scan_001.png
#   inflating: data/receipt_validation/train/non_receipt/scan_002.png
#   inflating: data/receipt_validation/train/non_receipt/scan_003.png
#   inflating: data/receipt_validation/train/non_receipt/scan_004.png
#   inflating: data/receipt_validation/train/non_receipt/scan_005.png
#   inflating: data/receipt_validation/train/non_receipt/scan_006.png
#   inflating: data/receipt_validation/train/non_receipt/scan_007.png
#   inflating: data/receipt_validation/train/non_receipt/scan_008.png
#   inflating: data/receipt_validation/train/non_receipt/scan_009.png
#   inflating: data/receipt_validation/train/non_receipt/scan_010.png
#   inflating: data/receipt_validation/train/non_receipt/scan_011.png
#   inflating: data/receipt_validation/train/non_receipt/scan_012.png
#   inflating: data/receipt_validation/train/non_receipt/scan_013.png
#   inflating: data/receipt_validation/train/non_receipt/scan_014.png
#   inflating: data/receipt_validation/train/non_receipt/scan_015.png
#   inflating: data/receipt_validation/train/non_receipt/scan_016.png
#   inflating: data/receipt_validation/train/non_receipt/scan_017.png
#   inflating: data/receipt_validation/train/non_receipt/scan_018.png
#   inflating: data/receipt_validation/train/non_receipt/scan_019.png
#   inflating: data/receipt_validation/train/non_receipt/scan_020.png
#   inflating: data/receipt_validation/train/non_receipt/scan_186.png
#   inflating: data/receipt_validation/train/non_receipt/scan_187.png
#   inflating: data/receipt_validation/train/non_receipt/scan_188.png
#   inflating: data/receipt_validation/train/non_receipt/scan_189.png
#   inflating: data/receipt_validation/train/non_receipt/scan_190.png
#   inflating: data/receipt_validation/train/non_receipt/Selfie_7.jpg
#   inflating: data/receipt_validation/train/non_receipt/Selfie_8.jpg
#    creating: data/receipt_validation/train/receipt/
#   inflating: data/receipt_validation/train/receipt/X51007846301.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846302.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846305.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846307.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846309.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846325.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846326.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846366.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846368.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846370.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846388.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846391.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846393.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846395.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846398.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846410.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846412.jpg
#   inflating: data/receipt_validation/train/receipt/X51007846451.jpg
#   inflating: data/receipt_validation/train/receipt/X51008030560.jpg
#   inflating: data/receipt_validation/train/receipt/X51008030565.jpg
#   inflating: data/receipt_validation/train/receipt/X51008030566.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042777.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042778.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042782.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042783.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042791.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042792.jpg
#   inflating: data/receipt_validation/train/receipt/X51008042793.jpg
#   inflating: data/receipt_validation/train/receipt/X51008063849.jpg
#   inflating: data/receipt_validation/train/receipt/X51008064061.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099041.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099043.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099044.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099046.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099048.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099049.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099054.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099071.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099073.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099081.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099083.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099084.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099085.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099087.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099089.jpg
#   inflating: data/receipt_validation/train/receipt/X51008099102.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114216.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114217.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114260.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114262.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114266.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114281.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114282.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114283.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114284.jpg
#   inflating: data/receipt_validation/train/receipt/X51008114321.jpg
#   inflating: data/receipt_validation/train/receipt/X51008122920.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123446.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123447.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123450.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123451.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123476.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123580.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123586.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123599.jpg
#   inflating: data/receipt_validation/train/receipt/X51008123604.jpg
#   inflating: data/receipt_validation/train/receipt/X51008128052.jpg
#   inflating: data/receipt_validation/train/receipt/X51008128062.jpg
#   inflating: data/receipt_validation/train/receipt/X51008128065.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142005.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142030.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142031.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142032.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142033.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142034.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142038.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142058.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142059.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142060.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142061.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142062.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142063.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142065.jpg
#   inflating: data/receipt_validation/train/receipt/X51008142068.jpg
#   inflating: data/receipt_validation/train/receipt/X51008145450.jpg
#   inflating: data/receipt_validation/train/receipt/X51008145504.jpg
#   inflating: data/receipt_validation/train/receipt/X51008145505.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164420.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164510.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164524.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164525.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164969.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164991.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164992.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164996.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164997.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164998.jpg
#   inflating: data/receipt_validation/train/receipt/X51008164999.jpg
#   inflating: data/receipt_validation/train/receipt/X51009453801.jpg
#   inflating: data/receipt_validation/train/receipt/X51009453804.jpg
#    creating: data/receipt_validation/val/
#    creating: data/receipt_validation/val/non_receipt/
#   inflating: data/receipt_validation/val/non_receipt/10.jpg
#   inflating: data/receipt_validation/val/non_receipt/11.jpg
#   inflating: data/receipt_validation/val/non_receipt/12.jpg
#   inflating: data/receipt_validation/val/non_receipt/13.jpg
#   inflating: data/receipt_validation/val/non_receipt/14.jpg
#   inflating: data/receipt_validation/val/non_receipt/15.jpg
#   inflating: data/receipt_validation/val/non_receipt/22976.jpg
#   inflating: data/receipt_validation/val/non_receipt/22977.jpg
#   inflating: data/receipt_validation/val/non_receipt/22978.jpg
#   inflating: data/receipt_validation/val/non_receipt/22980.jpg
#   inflating: data/receipt_validation/val/non_receipt/22982.jpg
#   inflating: data/receipt_validation/val/non_receipt/22983.jpg
#   inflating: data/receipt_validation/val/non_receipt/22986.jpg
#   inflating: data/receipt_validation/val/non_receipt/22987.jpg
#   inflating: data/receipt_validation/val/non_receipt/22988.jpg
#   inflating: data/receipt_validation/val/non_receipt/22989.jpg
#   inflating: data/receipt_validation/val/non_receipt/22990.jpg
#   inflating: data/receipt_validation/val/non_receipt/22991.jpg
#   inflating: data/receipt_validation/val/non_receipt/22992.jpg
#   inflating: data/receipt_validation/val/non_receipt/22993.jpg
#   inflating: data/receipt_validation/val/non_receipt/22994.jpg
#   inflating: data/receipt_validation/val/non_receipt/9.jpg
#   inflating: data/receipt_validation/val/non_receipt/scan_176.png
#   inflating: data/receipt_validation/val/non_receipt/scan_177.png
#   inflating: data/receipt_validation/val/non_receipt/scan_178.png
#   inflating: data/receipt_validation/val/non_receipt/scan_179.png
#   inflating: data/receipt_validation/val/non_receipt/scan_180.png
#   inflating: data/receipt_validation/val/non_receipt/scan_226.png
#   inflating: data/receipt_validation/val/non_receipt/Selfie_4.jpg
#   inflating: data/receipt_validation/val/non_receipt/Selfie_7.jpg
#    creating: data/receipt_validation/val/receipt/
#   inflating: data/receipt_validation/val/receipt/X51007339139.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339146.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339150.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339151.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339152.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339156.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339157.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339158.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339162.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339164.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339165.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339166.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339167.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339639.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339642.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339643.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339647.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339648.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339650.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339651.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339653.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339656.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339657.jpg
#   inflating: data/receipt_validation/val/receipt/X51007339658.jpg
#   inflating: data/receipt_validation/val/receipt/X51007391372.jpg
#   inflating: data/receipt_validation/val/receipt/X51007419197.jpg
#   inflating: data/receipt_validation/val/receipt/X51007579726.jpg
#   inflating: data/receipt_validation/val/receipt/X51007846350.jpg
#   inflating: data/receipt_validation/val/receipt/X51007846353.jpg
#   inflating: data/receipt_validation/val/receipt/X51007846357.jpg

# %%
IMAGE_PATH = "/content/data/receipt_validation/train/receipt/X51007846301.jpg"

# %%
def run_ocr(image_path: str, lang: list = ["en"]):
    """
    Runs EasyOCR on an image and returns raw OCR results.

    Args:
        image_path (str): Path to receipt image.
        lang (list): Languages for OCR (default: English).

    Returns:
        results (list): List of tuples:
            [
              (bounding_box, text, confidence),
              ...
            ]
    """
    image = cv2.imread(image_path)

    if image is None:
        raise ValueError(f"Could not read image at path: {image_path}")

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    reader = easyocr.Reader(lang, gpu=False)
    results = reader.readtext(image_rgb)

    return results

# %%
def filter_ocr_by_confidence(results, min_conf: float = 0.5):
    """
    Filters OCR results based on confidence score.

    Args:
        results (list): Raw OCR output from EasyOCR.
        min_conf (float): Minimum confidence threshold.

    Returns:
        filtered_results (list): OCR results with confidence >= min_conf.
    """
    filtered_results = []

    for bbox, text, conf in results:
        if conf >= min_conf:
            filtered_results.append((bbox, text, conf))

    return filtered_results

# %%
def extract_text_lines(results):
    """
    Extracts text lines from OCR results and sorts them
    top-to-bottom based on bounding box positions.

    Args:
        results (list): OCR results (bbox, text, confidence)

    Returns:
        lines (list of str): Ordered text lines
    """


    extracted = []

    for bbox, text, conf in results:
        #bbox = [[x1,y1], [x2,y2], [x3,y3], [x4,y4]]
        #Take top-left corner (x1, y1)
        y_top = bbox[0][1]
        extracted.append((y_top, text))

    #Sort lines by y-coordinate
    extracted.sort(key=lambda x: x[0])

    #Return only text lines
    lines = [text for _, text in extracted]

    return lines

# %%
def normalize_line(line: str):
    line = line.lower().strip()
    line = re.sub(r"\s+", " ", line)
    line = re.sub(r'(?<=[a-z])1(?=[a-z])', 'l', line)
    line = line.replace("o.", "0.")
    line = line.replace("o,", "0,")
    line = line.replace("|", "1")

    return line


def normalize_lines(lines: list):
    return [normalize_line(line) for line in lines]

# %%
def extract_amount_from_line(line: str):
    """
    Extracts a numeric currency amount from a line of text.

    Handles formats like:
    - rm8.50
    - rm8,50
    - rm 8.50

    Returns:
        float or None
    """

    #Regex to capture currency amounts
    pattern = r"rm\s*([\d]+[.,][\d]{2})"

    match = re.search(pattern, line)
    if not match:
        return None

    amount_str = match.group(1)

    #Normalize comma to dot
    amount_str = amount_str.replace(",", ".")

    try:
        return float(amount_str)
    except ValueError:
        return None


def extract_final_total(lines: list):
    """
    Extracts the final payable total from OCR text lines.

    Strategy:
    1. Look for semantic keywords (nett total, grand total)
    2. Fallback to largest currency amount
    """

    keyword_priority = [
        "nett total",
        "grand total",
        "total payable",
        "amount payable"
    ]

    #Keyword-based extraction
    for line in lines:
        for keyword in keyword_priority:
            if keyword in line:
                amount = extract_amount_from_line(line)
                if amount is not None:
                    return amount

    #Fallback to largest amount
    amounts = []

    for line in lines:
        amount = extract_amount_from_line(line)
        if amount is not None:
            amounts.append(amount)

    if amounts:
        return max(amounts)

    return None

# %%
def extract_date(lines: list):
    """
    Extracts transaction date from OCR text lines.

    Supports formats like:
    - 10 jun 2018
    - 10/06/2018
    - 2018-06-10
    - 10 jun 2018 18.23
    """
    date_patterns = [
        r"\b\d{1,2}\s+(jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec)\s+\d{4}\b",
        r"\b\d{1,2}/\d{1,2}/\d{4}\b",
        r"\b\d{4}-\d{1,2}-\d{1,2}\b"
    ]

    for line in lines:
        for pattern in date_patterns:
            match = re.search(pattern, line)
            if match:
                return match.group(0)

    return None

# %%
def vendor_score(line: str):
    score = 0

    # Strong negative signals
    blacklist = ["invoice", "total", "gst", "tax", "receipt"]
    if any(b in line for b in blacklist):
        return -1

    # Alphabet dominance
    alpha_ratio = sum(c.isalpha() for c in line) / max(len(line), 1)
    if alpha_ratio > 0.6:
        score += 2

    # Length matters
    if len(line) >= 10:
        score += 2
    elif len(line) >= 6:
        score += 1

    # Multi-word bonus
    if len(line.split()) >= 2:
        score += 2

    # Business suffix bonus
    business_suffixes = ["ltd", "limited", "llp", "inc", "corp", "sdn", "bhd"]
    if any(s in line for s in business_suffixes):
        score += 3

    # Penalize digit-heavy lines
    if sum(c.isdigit() for c in line) > 3:
        score -= 2

    return score



def extract_vendor(lines: list):
    """
    Extract vendor name using scoring-based heuristics.
    """

    candidates = lines[:6]  # top region only

    scored = [(vendor_score(line), line) for line in candidates]

    # Remove impossible candidates
    scored = [item for item in scored if item[0] > 0]

    if not scored:
        return None

    # Pick highest scoring line
    scored.sort(reverse=True, key=lambda x: x[0])
    return scored[0][1]

# %%
def extract_receipt_entities(lines: list):
    """
    Extracts key structured entities from OCR text lines.

    Entities:
        - vendor name
        - transaction date
        - final payable total

    Args:
        lines (list): Normalized OCR text lines (ordered top-to-bottom)

    Returns:
        dict: Structured receipt entities
    """
    vendor = extract_vendor(lines)
    date = extract_date(lines)
    total = extract_final_total(lines)

    return {
        "vendor": vendor,
        "date": date,
        "total": total
    }

# %%
results = run_ocr(IMAGE_PATH)
results[:5]
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[np.int32(2667), np.int32(1203)],
#    [np.int32(3098), np.int32(1203)],
#    [np.int32(3098), np.int32(1361)],
#    [np.int32(2667), np.int32(1361)]],
#   'Hoboz',
#   np.float64(0.5182740976238969)),
#  ([[np.int32(1630), np.int32(1455)],
#    [np.int32(2984), np.int32(1455)],
#    [np.int32(2984), np.int32(1559)],
#    [np.int32(1630), np.int32(1559)]],
#   'UNIHAKKA INTERNATIONAL SDN BHD',
#   np.float64(0.9856849153772583)),
#  ([[np.int32(2059), np.int32(1536)],
#    [np.int32(2555), np.int32(1536)],
#    [np.int32(2555), np.int32(1620)],
#    [np.int32(2059), np.int32(1620)]],
#   '10 Jun 2018 18.23',
#   np.float64(0.9902464752058203)),
#  ([[np.int32(2146), np.int32(1621)],
#    [np.int32(2469), np.int32(1621)],
#    [np.int32(2469), np.int32(1712)],
#    [np.int32(2146), np.int32(1712)]],
#   '(867388-U)',
#   np.float64(0.7024909255879769)),
#  ([[np.int32(1729), np.int32(1702)],
#    [np.int32(2891), np.int32(1702)],
#    [np.int32(2891), np.int32(1802)],
#    [np.int32(1729), np.int32(1802)]],
#   '12, Jalan Tampoi 7/4,Kawasan Perindustrian',
#   np.float64(0.815579933608002))]

# %%
filtered_results = filter_ocr_by_confidence(results, min_conf=0.5)
len(results), len(filtered_results)
# Out:
# (43, 41)

# %%
lines = extract_text_lines(filtered_results)
for line in lines:
    print(line)
# Out:
# Hoboz
# UNIHAKKA INTERNATIONAL SDN BHD
# 10 Jun 2018 18.23
# (867388-U)
# 12, Jalan Tampoi 7/4,Kawasan Perindustrian
# Tampoi,81200 Johor Bahru,Johor
# TAX INVOICE
# OR18061002160368
# Invoice #
# Total
# Qty
# Item
# SR 100100000171-Meat Dish
# RM2.83
# RM2.83
# SR 100100000031
# 3 Vege
# RM4.15
# SR /00100000170- Imported Veggies
# RM1.50
# RM1.50
# Total Amount: RM8.48
# GST @O%: RMO.OO
# Rounding: RMO.02
# Nett Total: RM8.50
# Amount
# Payment Mode_
# RM8,50
# CASH
# RMO.00
# Change
# TaxRM)
# Amount(RM)
# GST Summary
# 8.48
# SR = GST @0%
# GST REG #000656195584
# BAR WANG RICE@PERMAS JAYA
# Thank You & Come Againl
# Like and Follow Us on Facebookl
# Facebook com/BarWangRice

# %%
clean_lines = normalize_lines(lines)
for l in clean_lines:
    print(l)
# Out:
# hoboz
# unihakka international sdn bhd
# 10 jun 2018 18.23
# (867388-u)
# 12, jalan tampoi 7/4,kawasan perindustrian
# tampoi,81200 johor bahru,johor
# tax invoice
# or18061002160368
# invoice #
# total
# qty
# item
# sr 100100000171-meat dish
# rm2.83
# rm2.83
# sr 100100000031
# 3 vege
# rm4.15
# sr /00100000170- imported veggies
# rm1.50
# rm1.50
# total amount: rm8.48
# gst @o%: rm0.oo
# rounding: rm0.02
# nett total: rm8.50
# amount
# payment mode_
# rm8,50
# cash
# rm0.00
# change
# taxrm)
# amount(rm)
# gst summary
# 8.48
# sr = gst @0%
# gst reg #000656195584
# bar wang rice@permas jaya
# thank you & come againl
# like and follow us on facebookl
# facebook com/barwangrice

# %%
final_total = extract_final_total(clean_lines)
final_total
# Out:
# 8.5

# %%
date = extract_date(clean_lines)
date
# Out:
# '10 jun 2018'

# %%
vendor = extract_vendor(clean_lines)
vendor
# Out:
# 'unihakka international sdn bhd'

# %%
entities = extract_receipt_entities(clean_lines)
entities
# Out:
# {'vendor': 'unihakka international sdn bhd',
#  'date': '10 jun 2018',
#  'total': 8.5}
